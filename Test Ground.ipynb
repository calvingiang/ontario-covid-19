# %%
import pandas
import requests
from get_data import get_ontario_data

# %%
def get_ontario_cases():
    base_url = 'https://data.ontario.ca'
    record_length = 1
    record_num = 0
    covid_df = pandas.DataFrame()

    path_url = '/api/3/action/datastore_search?&resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=1000000'
    url = base_url + path_url.format(str(record_num))
    covid_request = requests.get(url)
    records = covid_request.json()['result']['records']
    new_df = pandas.DataFrame(records)
    covid_df = pandas.concat([covid_df, new_df])
    record_length = len(records)
    record_num=record_num+1
    return covid_df

# %%
def get_ontario_cases():
    base_url = 'https://data.ontario.ca'
    covid_df = pandas.DataFrame()

    path_url = '/api/3/action/datastore_search?&resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=1000000'
    url = base_url + path_url
    covid_request = requests.get(url)
    records = covid_request.json()['result']['records']
    new_df = pandas.DataFrame(records)
    covid_df = pandas.concat([covid_df, new_df])
    return covid_df

# %%
def get_cases_only():
    covid_cases = get_ontario_cases()
    cases_df = covid_cases[['Reported Date', 'Total Cases']]
    cases_df = cases_df[['Reported Date','Total Cases']].fillna(0).reset_index().drop(columns=['index'])
    previous_cases = cases_df
    previous_cases = previous_cases.shift(periods=1).fillna(0).drop(columns=['Reported Date']).rename(columns={'Total Cases':'Yesterday Cases'})
    cases_df = pandas.merge(cases_df, previous_cases, left_index=True, right_index=True)
    cases_df['New Cases'] = cases_df['Total Cases'] - cases_df['Yesterday Cases']
    cases_df = cases_df[['Reported Date', 'Total Cases', 'New Cases']]
    cases_df['Reported Date'] = cases_df['Reported Date'].apply(time_format)
    return cases_df

# %%
df = get_cases_only()

# %%
df.tail()
# Out:
#     Reported Date  Total Cases  New Cases
# 566    2021-08-25     561297.0      660.0
# 567    2021-08-26     561975.0      678.0
# 568    2021-08-27     562756.0      781.0
# 569    2021-08-28     563591.0      835.0
# 570    2021-08-29     564331.0      740.0

# %%
def get_ontario_data():

    base_url = 'https://data.ontario.ca'
    covid_df = pandas.DataFrame()

    path_url = '/api/3/action/datastore_search?&resource_id=455fd63b-603d-4608-8216-7d8647f43350&limit=1000000'
    url = base_url + path_url
    covid_request = requests.get(url)
    records = covid_request.json()['result']['records']
    new_df = pandas.DataFrame(records)
    covid_df = pandas.concat([covid_df, new_df])

    return covid_df
def ontario_other_data():
    # df = pandas.read_csv('./src/ontario.csv')
    df =  get_ontario_data()
    return df.iloc[:, 3:]

# %%
ontario_other_data_df = ontario_other_data()

# %%
ontario_other_data_df.head()
# Out:
#     Case_Reported_Date   Test_Reported_Date        Specimen_Date Age_Group  \
# 0  2020-05-05T00:00:00  2020-05-05T00:00:00  2020-05-03T00:00:00       50s
# 1  2020-10-21T00:00:00  2020-11-21T00:00:00  2019-11-20T00:00:00       20s
# 2  2020-04-24T00:00:00  2020-04-24T00:00:00  2020-04-23T00:00:00       80s
# 3  2020-05-17T00:00:00  2020-05-17T00:00:00  2020-05-15T00:00:00       50s
# 4  2021-05-26T00:00:00  2021-03-31T00:00:00  2021-03-28T00:00:00   UNKNOWN
#
#   Client_Gender Case_AcquisitionInfo  Outcome1 Outbreak_Related  \
# 0        FEMALE                   CC  Resolved
# 1        FEMALE    NO KNOWN EPI LINK  Resolved
# 2          MALE    NO KNOWN EPI LINK  Resolved
# 3          MALE                   CC  Resolved
# 4          MALE               TRAVEL  Resolved
#
#    Reporting_PHU_ID                        Reporting_PHU  \
# 0              2260  Simcoe Muskoka District Health Unit
# 1              4913           Southwestern Public Health
# 2              2234        Haldimand-Norfolk Health Unit
# 3              2265    Region of Waterloo, Public Health
# 4              2263              Timiskaming Health Unit
#
#            Reporting_PHU_Address Reporting_PHU_City Reporting_PHU_Postal_Code  \
# 0              15 Sperling Drive             Barrie                   L4M 6K9
# 1             1230 Talbot Street         St. Thomas                   N5P 1G9
# 2            12 Gilbertson Drive             Simcoe                   N3Y 4N5
# 3         99 Regina Street South           Waterloo                   N2J 4V3
# 4  247 Whitewood Avenue, Unit 43       New Liskeard                   P0J 1P0
#
#          Reporting_PHU_Website  Reporting_PHU_Latitude  \
# 0  www.simcoemuskokahealth.org               44.410713
# 1        www.swpublichealth.ca               42.777804
# 2                 www.hnhu.org               42.847825
# 3      www.regionofwaterloo.ca               43.462876
# 4        www.timiskaminghu.com               47.509284
#
#    Reporting_PHU_Longitude
# 0               -79.686306
# 1               -81.151156
# 2               -80.303815
# 3               -80.520913
# 4               -79.681632

# %%
get_ontario_data().head()
# Out:
#    _id  Row_ID Accurate_Episode_Date   Case_Reported_Date  \
# 0    1       1   2019-05-30T00:00:00  2020-05-05T00:00:00
# 1    2       2   2019-11-20T00:00:00  2020-10-21T00:00:00
# 2    3       3   2020-01-01T00:00:00  2020-04-24T00:00:00
# 3    4       4   2020-01-01T00:00:00  2020-05-17T00:00:00
# 4    5       5   2020-01-01T00:00:00  2021-05-26T00:00:00
#
#     Test_Reported_Date        Specimen_Date Age_Group Client_Gender  \
# 0  2020-05-05T00:00:00  2020-05-03T00:00:00       50s        FEMALE
# 1  2020-11-21T00:00:00  2019-11-20T00:00:00       20s        FEMALE
# 2  2020-04-24T00:00:00  2020-04-23T00:00:00       80s          MALE
# 3  2020-05-17T00:00:00  2020-05-15T00:00:00       50s          MALE
# 4  2021-03-31T00:00:00  2021-03-28T00:00:00   UNKNOWN          MALE
#
#   Case_AcquisitionInfo  Outcome1 Outbreak_Related  Reporting_PHU_ID  \
# 0                   CC  Resolved                               2260
# 1    NO KNOWN EPI LINK  Resolved                               4913
# 2    NO KNOWN EPI LINK  Resolved                               2234
# 3                   CC  Resolved                               2265
# 4               TRAVEL  Resolved                               2263
#
#                          Reporting_PHU          Reporting_PHU_Address  \
# 0  Simcoe Muskoka District Health Unit              15 Sperling Drive
# 1           Southwestern Public Health             1230 Talbot Street
# 2        Haldimand-Norfolk Health Unit            12 Gilbertson Drive
# 3    Region of Waterloo, Public Health         99 Regina Street South
# 4              Timiskaming Health Unit  247 Whitewood Avenue, Unit 43
#
#   Reporting_PHU_City Reporting_PHU_Postal_Code        Reporting_PHU_Website  \
# 0             Barrie                   L4M 6K9  www.simcoemuskokahealth.org
# 1         St. Thomas                   N5P 1G9        www.swpublichealth.ca
# 2             Simcoe                   N3Y 4N5                 www.hnhu.org
# 3           Waterloo                   N2J 4V3      www.regionofwaterloo.ca
# 4       New Liskeard                   P0J 1P0        www.timiskaminghu.com
#
#    Reporting_PHU_Latitude  Reporting_PHU_Longitude
# 0               44.410713               -79.686306
# 1               42.777804               -81.151156
# 2               42.847825               -80.303815
# 3               43.462876               -80.520913
# 4               47.509284               -79.681632
